# %%
import pandas as pd

# %%
# Loading csv data frame
csv_df=pd.read_csv('data/cars.csv')
csv_df
# Out:
#      buying  maint  doors persons lug_boot safety evaluation
# 0     vhigh  vhigh      2       2    small    low      unacc
# 1     vhigh  vhigh      2       2    small    med      unacc
# 2     vhigh  vhigh      2       2    small   high      unacc
# 3     vhigh  vhigh      2       2      med    low      unacc
# 4     vhigh  vhigh      2       2      med    med      unacc
# 5     vhigh  vhigh      2       2      med   high      unacc
# 6     vhigh  vhigh      2       2      big    low      unacc
# 7     vhigh  vhigh      2       2      big    med      unacc
# 8     vhigh  vhigh      2       2      big   high      unacc
# 9     vhigh  vhigh      2       4    small    low      unacc
# 10    vhigh  vhigh      2       4    small    med      unacc
# 11    vhigh  vhigh      2       4    small   high      unacc
# 12    vhigh  vhigh      2       4      med    low      unacc
# 13    vhigh  vhigh      2       4      med    med      unacc
# ...

# %%
# Getting 5 rows of data frame
csv_subsetrows=csv_df[0:5]
csv_subsetrows
# Out:
#   buying  maint doors persons lug_boot safety evaluation
# 0  vhigh  vhigh     2       2    small    low      unacc
# 1  vhigh  vhigh     2       2    small    med      unacc
# 2  vhigh  vhigh     2       2    small   high      unacc
# 3  vhigh  vhigh     2       2      med    low      unacc
# 4  vhigh  vhigh     2       2      med    med      unacc

# %%
# Fetching subset of coulmns
csv_df_subsetcol=csv_subsetrows[['doors', 'persons','lug_boot','safety']]
csv_df_subsetcol
# Out:
#   doors persons lug_boot safety
# 0     2       2    small    low
# 1     2       2    small    med
# 2     2       2    small   high
# 3     2       2      med    low
# 4     2       2      med    med

# %%
# Importing books
import json
with open('data/books.json', encoding = 'utf-8') as f:
    books_dict = json.load(f)
# Subset of Json document
from pprint import pprint
pprint(books_dict[0])
# Out:
# {'_id': 1,
#  'authors': ['W. Frank Ableson', 'Charlie Collins', 'Robi Sen'],
#  'categories': ['Open Source', 'Mobile'],
#  'isbn': '1933988673',
#  'longDescription': 'Android is an open source mobile phone platform based on '
#                     'the Linux operating system and developed by the Open '
#                     'Handset Alliance, a consortium of over 30 hardware, '
#                     'software and telecom companies that focus on open '
#                     'standards for mobile devices. Led by search giant, '
#                     'Google, Android is designed to deliver a better and more '
#                     'open and cost effective mobile experience.    Unlocking '
#                     "Android: A Developer's Guide provides concise, hands-on "
#                     'instruction for the Android operating system and '
#                     'development tools. This book teaches important '
# ...

# %%
# Printing keys of json
json_keys=books_dict[0].keys()
json_keys
# Out:
# dict_keys(['_id', 'title', 'isbn', 'pageCount', 'publishedDate', 'thumbnailUrl', 'shortDescription', 'longDescription', 'status', 'authors', 'categories'])

# %%
from PIL import Image

# %%
# opening image
img = Image.open("data/uw_logo.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200 at 0x11B1A9DA0>

# %%
# Converting image in binary format
from matplotlib.image import imread
# Subset of the image
img = imread('data/uw_logo.jpg')
img[0:1]
# Out:
# array([[[56, 39, 91],
#         [56, 39, 91],
#         [56, 39, 91],
#         ...,
#         [56, 39, 91],
#         [56, 39, 91],
#         [56, 39, 91]]], dtype=uint8)

# %%
from ruamel.yaml import YAML
from pathlib import Path

path = Path('data/spen.yml')

# %%
# Opening the yaml file
yaml = YAML(typ='safe')
data = yaml.load(path)
data
# Out:
# [{'EN': 'he dropped the cup on the floor',
#   'SP': ['se le cayó la taza al suelo', 'dejo caer la taza al suelo'],
#   'tags': {'sp': None, 'en': None, 'diff': 4}},
#  {'EN': 'in bad times you really get to know your friends',
#   'SP': 'en las malas se conocen a los amigos',
#   'tags': {'sp': 'proverb', 'en': None, 'diff': 2}},
#  {'EN': 'to each their own',
#   'SP': 'cada loco con su tema',
#   'tags': {'sp': 'idiom', 'en': 'idiom', 'diff': 2}},
#  {'EN': "I'd like to return the favor for their generosity",
#   'SP': 'quisiera corresponder a su generosidad',
#   'tags': {'sp': None, 'en': None, 'diff': None}},
#  {'EN': 'he loves her but she responds with contempt and rudeness',
#   'SP': 'la ama y ella le corresponde con desprecio y grosería',
#   'tags': {'sp': None, 'en': None, 'diff': None}},
#  {'EN': 'a story of unrequited love',
#   'SP': 'la historia de un amor no correspondido',
#   'tags': {'sp': None, 'en': None, 'diff': None}},
# ...

# %%
# extracting subset of data
data[0]
# Out:
# {'EN': 'he dropped the cup on the floor',
#  'SP': ['se le cayó la taza al suelo', 'dejo caer la taza al suelo'],
#  'tags': {'sp': None, 'en': None, 'diff': 4}}
